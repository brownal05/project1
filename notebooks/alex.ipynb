# %%
#data explorer
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint

url = ""
summary_by_year = requests.get(f"https://banks.data.fdic.gov/api/summary?filters=STNAME%3A%22Alabama%22&fields=STNAME%2CYEAR%2CINTINC%2CEINTEXP%2CNIM%2CNONII%2CNONIX%2CELNATR%2CITAXR%2CIGLSEC%2CITAX%2CEXTRA%2CNETINC&sort_by=YEAR&sort_order=DESC&limit=10&offset=0&format=json").json()

# %%
pprint(summary_by_year)
# Out:
# {'data': [{'data': {'EINTEXP': 919157,
#                     'ELNATR': 526215,
#                     'EXTRA': 0,
#                     'IGLSEC': 26973,
#                     'INTINC': 8597659,
#                     'ITAX': 1221536,
#                     'ITAXR': 3510133,
#                     'NETINC': 2311678,
#                     'NIM': 7678502,
#                     'NONII': 3085435,
#                     'NONIX': 6727589,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2017'}},
#           {'data': {'EINTEXP': 3922,
#                     'ELNATR': 47,
#                     'EXTRA': 0,
#                     'IGLSEC': 19,
#                     'INTINC': 21221,
#                     'ITAX': 1828,
#                     'ITAXR': 4809,
#                     'NETINC': 3000,
#                     'NIM': 17299,
#                     'NONII': 12093,
#                     'NONIX': 24536,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2017'}},
#           {'data': {'EINTEXP': 3805,
#                     'ELNATR': 306,
#                     'EXTRA': 0,
#                     'IGLSEC': 80,
#                     'INTINC': 20651,
#                     'ITAX': 1500,
#                     'ITAXR': 4989,
#                     'NETINC': 3569,
#                     'NIM': 16846,
#                     'NONII': 12712,
#                     'NONIX': 24263,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2016'}},
#           {'data': {'EINTEXP': 842847,
#                     'ELNATR': 670092,
#                     'EXTRA': 0,
#                     'IGLSEC': 52486,
#                     'INTINC': 7994518,
#                     'ITAX': 861640,
#                     'ITAXR': 2945067,
#                     'NETINC': 2132325,
#                     'NIM': 7151671,
#                     'NONII': 3099268,
#                     'NONIX': 6635780,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2016'}},
#           {'data': {'EINTEXP': 5961,
#                     'ELNATR': 189,
#                     'EXTRA': 0,
#                     'IGLSEC': 53,
#                     'INTINC': 27629,
#                     'ITAX': 1160,
#                     'ITAXR': -382,
#                     'NETINC': -1489,
#                     'NIM': 21668,
#                     'NONII': 14430,
#                     'NONIX': 36291,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2015'}},
#           {'data': {'EINTEXP': 767215,
#                     'ELNATR': 526832,
#                     'EXTRA': 0,
#                     'IGLSEC': 119697,
#                     'INTINC': 7636731,
#                     'ITAX': 778114,
#                     'ITAXR': 2646849,
#                     'NETINC': 1984135,
#                     'NIM': 6869516,
#                     'NONII': 2833152,
#                     'NONIX': 6528987,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2015'}},
#           {'data': {'EINTEXP': 6227,
#                     'ELNATR': 237,
#                     'EXTRA': 0,
#                     'IGLSEC': -478,
#                     'INTINC': 31298,
#                     'ITAX': 1173,
#                     'ITAXR': 2741,
#                     'NETINC': 1090,
#                     'NIM': 25071,
#                     'NONII': 16135,
#                     'NONIX': 38228,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2014'}},
#           {'data': {'EINTEXP': 734965,
#                     'ELNATR': 240584,
#                     'EXTRA': -5,
#                     'IGLSEC': 92495,
#                     'INTINC': 7515504,
#                     'ITAX': 854858,
#                     'ITAXR': 2880306,
#                     'NETINC': 2115450,
#                     'NIM': 6780539,
#                     'NONII': 2767424,
#                     'NONIX': 6427073,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2014'}},
#           {'data': {'EINTEXP': 7696,
#                     'ELNATR': 2450,
#                     'EXTRA': -3760,
#                     'IGLSEC': 331,
#                     'INTINC': 37828,
#                     'ITAX': 1100,
#                     'ITAXR': -4137,
#                     'NETINC': -8666,
#                     'NIM': 30132,
#                     'NONII': 14438,
#                     'NONIX': 46257,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2013'}},
#           {'data': {'EINTEXP': 757892,
#                     'ELNATR': 338149,
#                     'EXTRA': 0,
#                     'IGLSEC': 70486,
#                     'INTINC': 7540854,
#                     'ITAX': 751574,
#                     'ITAXR': 2794739,
#                     'NETINC': 2106983,
#                     'NIM': 6782962,
#                     'NONII': 2860131,
#                     'NONIX': 6510205,
#                     'STNAME': 'Alabama',
#                     'YEAR': '2013'}}],
#  'meta': {'index': {'createTimestamp': '2018-12-31T21:13:08Z',
#                     'name': 'historical_1546290788292'},
#           'parameters': {'fields': 'STNAME,YEAR,INTINC,EINTEXP,NIM,NONII,NONIX,ELNATR,ITAXR,IGLSEC,ITAX,EXTRA,NETINC',
#                          'filters': 'STNAME:"Alabama"',
#                          'limit': '10',
#                          'offset': '0'},
#           'total': 118},
#  'totals': {'count': 118}}
