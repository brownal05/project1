# %%
#data explorer
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint

url = ""
summary_by_year = requests.get(f"https://banks.data.fdic.gov/api/summary?filters=STNAME%3A%22Alabama%22&fields=STNAME%2CYEAR%2CINTINC%2CEINTEXP%2CNIM%2CNONII%2CNONIX%2CELNATR%2CITAXR%2CIGLSEC%2CITAX%2CEXTRA%2CNETINC&sort_by=YEAR&sort_order=DESC&limit=10&offset=0&format=json").json()

# %%
summary_by_year
# Out:
# {'meta': {'total': 118,
#   'parameters': {'filters': 'STNAME:"Alabama"',
#    'fields': 'STNAME,YEAR,INTINC,EINTEXP,NIM,NONII,NONIX,ELNATR,ITAXR,IGLSEC,ITAX,EXTRA,NETINC',
#    'limit': '10',
#    'offset': '0'},
#   'index': {'name': 'historical_1546290788292',
#    'createTimestamp': '2018-12-31T21:13:08Z'}},
#  'data': [{'data': {'ITAX': 1221536,
#     'EINTEXP': 919157,
#     'EXTRA': 0,
#     'ELNATR': 526215,
#     'STNAME': 'Alabama',
#     'INTINC': 8597659,
#     'NETINC': 2311678,
#     'NONIX': 6727589,
#     'NIM': 7678502,
#     'YEAR': '2017',
#     'ITAXR': 3510133,
#     'IGLSEC': 26973,
#     'NONII': 3085435}},
#   {'data': {'ITAX': 1828,
#     'EINTEXP': 3922,
#     'EXTRA': 0,
#     'ELNATR': 47,
#     'STNAME': 'Alabama',
#     'INTINC': 21221,
#     'NETINC': 3000,
#     'NONIX': 24536,
#     'NIM': 17299,
#     'YEAR': '2017',
#     'ITAXR': 4809,
#     'IGLSEC': 19,
#     'NONII': 12093}},
#   {'data': {'ITAX': 1500,
#     'EINTEXP': 3805,
#     'EXTRA': 0,
#     'ELNATR': 306,
#     'STNAME': 'Alabama',
#     'INTINC': 20651,
#     'NETINC': 3569,
#     'NONIX': 24263,
#     'NIM': 16846,
#     'YEAR': '2016',
#     'ITAXR': 4989,
#     'IGLSEC': 80,
#     'NONII': 12712}},
#   {'data': {'ITAX': 861640,
#     'EINTEXP': 842847,
#     'EXTRA': 0,
#     'ELNATR': 670092,
#     'STNAME': 'Alabama',
#     'INTINC': 7994518,
#     'NETINC': 2132325,
#     'NONIX': 6635780,
#     'NIM': 7151671,
#     'YEAR': '2016',
#     'ITAXR': 2945067,
#     'IGLSEC': 52486,
#     'NONII': 3099268}},
#   {'data': {'ITAX': 1160,
#     'EINTEXP': 5961,
#     'EXTRA': 0,
#     'ELNATR': 189,
#     'STNAME': 'Alabama',
#     'INTINC': 27629,
#     'NETINC': -1489,
#     'NONIX': 36291,
#     'NIM': 21668,
#     'YEAR': '2015',
#     'ITAXR': -382,
#     'IGLSEC': 53,
#     'NONII': 14430}},
#   {'data': {'ITAX': 778114,
#     'EINTEXP': 767215,
#     'EXTRA': 0,
#     'ELNATR': 526832,
#     'STNAME': 'Alabama',
#     'INTINC': 7636731,
#     'NETINC': 1984135,
#     'NONIX': 6528987,
#     'NIM': 6869516,
#     'YEAR': '2015',
#     'ITAXR': 2646849,
#     'IGLSEC': 119697,
#     'NONII': 2833152}},
#   {'data': {'ITAX': 1173,
#     'EINTEXP': 6227,
#     'EXTRA': 0,
#     'ELNATR': 237,
#     'STNAME': 'Alabama',
#     'INTINC': 31298,
#     'NETINC': 1090,
#     'NONIX': 38228,
#     'NIM': 25071,
#     'YEAR': '2014',
#     'ITAXR': 2741,
#     'IGLSEC': -478,
#     'NONII': 16135}},
#   {'data': {'ITAX': 854858,
#     'EINTEXP': 734965,
#     'EXTRA': -5,
#     'ELNATR': 240584,
#     'STNAME': 'Alabama',
#     'INTINC': 7515504,
#     'NETINC': 2115450,
#     'NONIX': 6427073,
#     'NIM': 6780539,
#     'YEAR': '2014',
#     'ITAXR': 2880306,
#     'IGLSEC': 92495,
#     'NONII': 2767424}},
#   {'data': {'ITAX': 1100,
#     'EINTEXP': 7696,
#     'EXTRA': -3760,
#     'ELNATR': 2450,
#     'STNAME': 'Alabama',
#     'INTINC': 37828,
#     'NETINC': -8666,
#     'NONIX': 46257,
#     'NIM': 30132,
#     'YEAR': '2013',
#     'ITAXR': -4137,
#     'IGLSEC': 331,
#     'NONII': 14438}},
#   {'data': {'ITAX': 751574,
#     'EINTEXP': 757892,
#     'EXTRA': 0,
#     'ELNATR': 338149,
#     'STNAME': 'Alabama',
#     'INTINC': 7540854,
#     'NETINC': 2106983,
#     'NONIX': 6510205,
#     'NIM': 6782962,
#     'YEAR': '2013',
#     'ITAXR': 2794739,
#     'IGLSEC': 70486,
#     'NONII': 2860131}}],
#  'totals': {'count': 118}}
