# %%
#data explorer
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint
import csv
import matplotlib.pyplot as plt
#url = ""
#summary_by_year = requests.get(f"https://banks.data.fdic.gov/api/summary?filters=STNAME%3A%22Alabama%22&fields=STNAME%2CYEAR%2CINTINC%2CEINTEXP%2CNIM%2CNONII%2CNONIX%2CELNATR%2CITAXR%2CIGLSEC%2CITAX%2CEXTRA%2CNETINC&sort_by=YEAR&sort_order=DESC&limit=10&offset=0&format=json").json()

# %%
#pprint(summary_by_year)

# %%
data = "../raw-data/aggregate_bank_data.csv"
agg_df = pd.read_csv(data)

# %%
agg_df
# Out:
#           ASSET          DEP     NETINC                       STNAME  \
# 0   16219706328  12468181063  152184632  United States & Other Areas
# 1   15627691877  11982312148  156984561  United States & Other Areas
# 2   14893189603  11349503567  151888582  United States & Other Areas
# 3   14474657532  10938732842  140189718  United States & Other Areas
# 4   13673056712  10385833653  143110234  United States & Other Areas
# 5   13387499239  10012097628  130041412  United States & Other Areas
# 6   12650468093   9258874267  110182982  United States & Other Areas
# 7   12069442602   8517722866   77427236  United States & Other Areas
# 8   11826781868   8336603049  -11619811  United States & Other Areas
# 9   12313141199   8085709986   15262023  United States & Other Areas
# 10  11181900787   7313861237   97639154  United States & Other Areas
# 11  10097741906   6735638819  128266630  United States & Other Areas
# 12   9046945908   6077508026  113965005  United States & Other Areas
# 13   8420099062   5596572154  104021848  United States & Other Areas
# 14   7601000415   5034669168  102566180  United States & Other Areas
# 15   7076844192   4689787744   89439142  United States & Other Areas
# 16   6552293846   4377557731   74131124  United States & Other Areas
# 17   6245559732   4179567486   70795046  United States & Other Areas
# 18   5735134597   3831058463   71527729  United States & Other Areas
# 19   5442603969   3681390727   61885315  United States & Other Areas
# 20   5018532250   3421663524   59159284  United States & Other Areas
# 21   4582164804   3197138558   52324224  United States & Other Areas
#
#           TPD  YEAR
# 0   105830699  2017
# 1   107003240  2016
# 2   113542465  2015
# 3   134262032  2014
# 4   160802005  2013
# 5   197325829  2012
# 6   218578920  2011
# 7   229682914  2010
# 8   251462891  2009
# 9   202283447  2008
# 10  114678376  2007
# 11   78973321  2006
# 12   64471379  2005
# 13   57202202  2004
# 14   60999898  2003
# 15   63078890  2002
# 16   66339653  2001
# 17   58747606  2000
# 18   49271154  1999
# 19   51394497  1998
# 20   49265342  1997
# 21   48179368  1996

# %%
bank_asset = agg_df["ASSET"]
bank_dep = agg_df["DEP"]
bank_netinc = agg_df["NETINC"]
bank_tpd = agg_df["TPD"]
headers = agg_df.columns
year= agg_df["YEAR"]
agg_df.plot(x='YEAR', y='TPD', rot=0)

# %%
plt.bar(year, bank_tpd, width=0.8)
# Out:
# <BarContainer object of 22 artists>

# %%
bank_csv = "../raw-data/bank-data.csv"
bank_data = agg_df = pd.read_csv(bank_csv)
bank_df = pd.DataFrame(bank_data)
bank_df
# Out:
#            ASSET  BANKS         DEP   EINTEXP    INTINC      LNCON       LNRE  \
# 0        4651727      4     3472798     10089    185709      35123    1664322
# 1      449683677    235   331003915   2252344  17551303   15142888  208604061
# 2      119582358    303    98757627    794436   4694560    4320157   47707735
# 3       37139895     23    11935994    172292   2767159   19262737    6769332
# 4       73622010     58    48597502    935212   2835324    1358944   42019915
# 5      653733790    118   478131308   2678438  13113827   11847405  109470262
# 6     1714023674     68  1275822739   6787467  48371990   86996140  548799888
# 7      222605668    134   174724044   1285604   8452265    7643078   92463798
# 8       55635156    101    45004098    440749   2337823    2121925   24432993
# 9       63017973    333    50656937    627557   2686088    1259102   24863995
# 10      48877126    120    40847150    430351   2257066    2300095   24190481
# 11      56523783    367    47936105    461382   2492782    1376071   24207076
# 12       2864026      7     2333257     27217    127380      11523    1709384
# 13    2457902396    148  1675386831  11801393  67745650  158048069  492780315
# 14      78353784    235    64503288    502955   3118964    2649678   27513406
# 15      34031676     31    24076291    199525   1497531     203959   21035294
# 16      79016687    237    63198918    650466   3281223    1529789   40273169
# 17       7391220     34     6298074     48463    291330     232307    2558378
# 18      95519414    204    78019697    713000   3650763    1532057   48086416
# 19     261726482    226   207081168   1710410  10017056   22982435  111535193
# 20       7368960     17     5935014     48241    324970      92474    2990833
# 21     370165909    498   304812857   2065479  10857005   11126257  121948023
# 22      52621024    178    42374346    503354   2414858    2049144   27698988
# 23      62299467    124    51062940    405877   2401562    2626102   25347743
# 24     241950339     25   186504325    575354   4061152     936439   15266942
# 25      56769690     84    46710946    429233   2421337    2028630   26878361
# 26      25463718     88    16695643    159735   1113849    2442136    8991258
# 27     128587385    130   101534109    999134   4857330    4698029   58778530
# 28    2493021260     78  1819689905  15514515  99367628  269937326  648179051
# 29      79408473    173    62861014    676360   3290152    2484848   37579783
# ...          ...    ...         ...       ...       ...        ...        ...
# 1218    54819832    577    46307121   2579758   4452627    5352996   15345777
# 1219   665892658    198   474435937  44582222  63676783   46236773   89811925
# 1220    66264299     71    48527235   3300462   5413202    6817370   18081245
# 1221   102434152    299    80932135   4933408   8775175   19716137   21795935
# 1222    19493598     52    15301908    816502   1628383    2750081    3885496
# 1223   160400128    293   122903644   7966631  12924815   15986720   30671035
# 1224    11168008     55     8784352    535382    993419    1946105    2902636
# 1225    61552344    184    48475812   3102484   5299966   11737228   16831214
# 1226    33582040     90    27979010   1510010   2982052    5607862    9091710
# 1227     4202408     95     3753726    183346    352326     350857     594233
# 1228    33606620    221    26958785   1642192   2801109    4653346    8276569
# 1229    28200702     47    23400301   1276565   2346267    4197498    8755756
# 1230    39541878     65    30092661   1909924   3277498    4185814   13960743
# 1231    59214182     46    26998968   3401649   6416258   34794777    3785637
# 1232   120273817    417   100306027   5419672   9832953   18097734   40396854
# 1233    48560471     99    37206104   2424834   4226437    7396403   14849340
# 1234    10457209     52     8507551    549139   1043687    2706667    3757390
# 1235     6904558    159     6109953    336738    600255     552285    1059429
# 1236    26114591    466    23081135   1228810   2167592    2123537    5029665
# 1237     4526956     10     3747807    212489    354004     227092    1043006
# 1238    59131170    379    45679876   2806287   5212062    9167849   14064599
# 1239    54226060    338    44253929   2568857   4394162    8082669   12840098
# 1240    30854367    585    26320233   1472707   2584025    3001938    5102461
# 1241     7754046     19     6431325    372605    685891    1182625    2939714
# 1242    52220656    653    41251682   2859374   4541073    5399700    9260589
# 1243     7074567    169     6130695    325654    611880     763834     929986
# 1244    13332819     17     6511131    600805   1433028    6818461    1664157
# 1245    14436037     12    10797210    748536   1260539    1216980    4161224
# 1246    20197558     77    15318087    924284   1694655    3399135    5474884
# 1247    22322849    133     8904175   1317308   2715064   14262846     966880
#
#         NETINC          STNAME       TPD  YEAR
# 0        53780          Alaska      7175  2011
# 1      4212106      California   3437273  2011
# 2       877597        Missouri    943278  2011
# 3      1663865          Nevada    667807  2011
# 4        15121      New Jersey   1348452  2011
# 5      5742525        New York   3007240  2011
# 6     10289058  North Carolina  54917711  2011
# 7     -1261060         Alabama   2370758  2011
# 8       485816         Indiana    461605  2011
# 9       666013            Iowa    265214  2011
# 10      234435        Michigan    640626  2011
# 11      394425       Minnesota    396535  2011
# 12       21147   New Hampshire      8258  2011
# 13    20597003            Ohio  32948613  2011
# 14      780029        Oklahoma    637562  2011
# 15      215275          Oregon    312378  2011
# 16      513773       Wisconsin    505988  2011
# 17       49814         Wyoming     38420  2011
# 18     -202029         Florida   1670117  2011
# 19      421391         Georgia   5182119  2011
# 20      -23441           Idaho     45583  2011
# 21     1470155        Illinois   4055679  2011
# 22      339326        Kentucky    467491  2011
# 23      446823       Louisiana    540257  2011
# 24     2053061   Massachusetts     98793  2011
# 25      414099     Mississippi    574819  2011
# 26      330519    North Dakota    212476  2011
# 27      961419    Pennsylvania    774693  2011
# 28    23951455    South Dakota  61161547  2011
# 29      195252       Tennessee    900206  2011
# ...        ...             ...       ...   ...
# 1218    468319        Missouri    633724  1988
# 1219   6804494        New York   6947529  1988
# 1220    700665  North Carolina    618858  1988
# 1221   1091232            Ohio   1313384  1988
# 1222    209132          Oregon    203242  1988
# 1223   1217618    Pennsylvania   1739037  1988
# 1224     35299            Utah    205920  1988
# 1225    644744        Virginia    837995  1988
# 1226    309183      Washington    535372  1988
# 1227     30819         Wyoming     56410  1988
# 1228    364297         Alabama    406179  1988
# 1229     62617         Arizona    722702  1988
# 1230    338604     Connecticut    746163  1988
# 1231    690329        Delaware   1386162  1988
# 1232    878213         Florida   1674211  1988
# 1233    421499        Maryland    530538  1988
# 1234     89077   New Hampshire    248168  1988
# 1235     34814    North Dakota     81462  1988
# 1236      -643        Oklahoma    307357  1988
# 1237   -132647          Alaska    113250  1988
# 1238    631548         Georgia    906020  1988
# 1239    528970         Indiana    537664  1988
# 1240    322485            Iowa    256970  1988
# 1241     91354           Maine    145124  1988
# 1242    177795       Minnesota    592788  1988
# 1243      2259         Montana    117602  1988
# 1244    216274          Nevada    192859  1988
# 1245    174802    Rhode Island    221713  1988
# 1246    190482  South Carolina    206716  1988
# 1247    401592    South Dakota   1229993  1988
#
# [1248 rows x 11 columns]

# %%
state = bank_df.groupby("STNAME")
debt = bank_df.groupby("TPD")
states = bank_df["STNAME"]
debts = bank_df["TPD"]/1000000
year = bank_df["YEAR"]

# %%
#state.plot(x='YEAR', y='TPD', rot=0, subplots=True)
#state.title(bank_df["STNNAME"], fontdict=None, loc='center', pad=None, **kwargs)[source]
plt.scatter(states,  year, s=debts)

# %%
 #http://localhost:8888/lab/tree/Documents%2Fclass%2Fproject1%2Fraw-data%2Fsep18_dec17.csv

# %%
SDI18["All Institutions - National"]
# Out:
# 0                       9/30/2018
# 1                      $ in 000's
# 2     Total (Sum) and Average (W)
# 3                            5477
# 4                             NaN
# 5                      63,299,064
# 6                      29,710,438
# 7                         279,222
# 8                      29,489,923
# 9                       1,294,539
# 10                        380,814
# 11                        913,725
# 12                        457,467
# 13                     23,914,536
# 14                        371,944
# 15                      3,451,437
# 16                      1,810,471
# 17                      1,640,966
# 18                      5,787,777
# 19                     11,943,666
# 20                      9,338,105
# 21                      3,350,003
# 22                     39,580,676
# 23                        439,098
# 24                     39,259,644
# 25                      1,337,243
# 26                        278,368
# 27                      1,058,875
# 28                      1,524,401
# 29                     28,435,731
#                  ...
# 36                              0
# 37                        174,745
# 38                     13,953,961
# 39                      1,606,652
# 40                      3,400,743
# 41                      1,143,257
# 42                      1,701,630
# 43                        555,856
# 44                         14,000
# 45                      2,046,398
# 46                        470,287
# 47                        333,609
# 48                        559,929
# 49                        709,046
# 50                      4,556,247
# 51                         69,857
# 52                            NaN
# 53                            NaN
# 54                            NaN
# 55                            NaN
# 56                            NaN
# 57                            NaN
# 58                            NaN
# 59                            NaN
# 60                            NaN
# 61                            NaN
# 62                            NaN
# 63                            NaN
# 64                            NaN
# 65                            NaN
# Name: All Institutions - National, Length: 66, dtype: object

# %%
debt_data = "../raw-data/fdicdata.csv"
debt = pd.read_csv(debt_data)

debt = debt.fillna(0)
debt.groupby('Year').sum()
debt['Other Loans'] = debt['Other Loans'] + debt['Auto Loans']
debt['Total Loans'] = debt['Total Loans'] + debt['Real Estate'] 
debt_clean = debt.drop(columns = ['Unnamed: 0','Auto Loans', 'State'])
debt_clean = debt_clean.sort_values('Year', ascending=True).reset_index().drop(columns = 'index')
debt_clean.to_csv('../raw-data/debt_clean.csv')
yr_tick = debt_clean['Year']

debt_clean.groupby('Year').sum().reset_index()
plt.axvspan(1990.75, 1991.25, 0.04, facecolor='yellow', alpha =.9)
plt.axvspan(2001.25, 2001.75, 0.04, facecolor='yellow', alpha =.9)
plt.axvspan(2007.9, 2009.5, 0.04, facecolor='yellow', alpha =.9)
yr_tick = debt_clean['Year']


debt_plot = plt.plot(debt_clean['Year'], debt_clean['Total Loans']/1000000000, 
          linestyle='none', )
plt.fill_between(debt_clean['Year'], debt_clean['Total Loans']/1000000000)
#plt.axvline(x=1996)
#plt.legend(['Recession 1990'], loc='lower left', 
#           bbox_to_anchor=[0.5, 1.1], 
#           fancybox=True, shadow=True)

plt.xticks(yr_tick, rotation='vertical')
plt.ticklabel_format(style='plain')

plt.title('Total US Debt 1987 to 2011')
plt.xlabel('Year')
plt.ylabel('Debt in Trillions (USD)')
plt.savefig('../graphs/tot_debt.png')
plt.show()

# %%
debt_clean
# Out:
#     Total Loans  Other Loans  Credit Cards  Real Estate  Total Past Due  Year
# 0     946685626  245471027.0     102514993    598699606        40563426  1987
# 1    1047845658  257762209.0     116786672    673296777        41180485  1988
# 2    1157141813  266883392.0     130974399    759284022        48058033  1989
# 3    1225215990  266413460.0     132911283    825891247        58032820  1990
# 4    1236973486  250462590.0     138534024    847976872        52539038  1991
# 5    1247429502  247248620.0     135834552    864346330        43288016  1992
# 6    1334881893  263489524.0     153800967    917591402        35896675  1993
# 7    1474612285  296457862.0     187704654    990449769        34451707  1994
# 8    1605144678  314878416.0     217761817   1072504445        41434525  1995
# 9    1690880054  325319914.0     234598883   1130961257        47557076  1996
# 10   1795183871  324818725.0     233832040   1236533106        48603940  1997
# 11   1900306996  336906090.0     227938907   1335461999        50651159  1998
# 12   2050908807  341480122.0     210887298   1498541387        48568598  1999
# 13   2259867396  352174242.0     248052161   1659640993        58015216  2000
# 14   2406884842  357954399.0     265228007   1783702436        65464713  2001
# 15   2746641149  384948237.0     312577515   2049115397        62070487  2002
# 16   3012997432  411909417.0     352091709   2248996306        60210170  2003
# 17   3430774344  423645837.0     409519282   2597609225        56343275  2004
# 18   3787238205  436032918.0     394655962   2956549325        63321345  2005
# 19   4248314500  463509287.0     386946868   3397858345        77396242  2006
# 20   4588235413  514724399.0     436808501   3636702513       112628427  2007
# 21   4791663667  527310794.0     464770322   3799582551       199005998  2008
# 22   4751869743  527520436.0     443100601   3781248706       248397175  2009
# 23   4834797236  511660000.0     708858981   3614278255       225155737  2010
# 24   4718556347  518791166.0     687774531   3511990650       214063792  2011

# %%
bar_real = debt_clean['Real Estate'].sum()/1000
bar_credit = debt_clean['Credit Cards'].sum()/1000
bar_other = debt_clean['Other Loans'].sum()/1000
debt_bar = (bar_real + bar_credit)

plt.bar(debt_clean['Year'], debt_clean['Real Estate']/1000000 )
plt.bar(debt_clean['Year'], debt_clean['Credit Cards']/1000000, bottom = debt_clean['Other Loans']/1000000)
plt.bar(debt_clean['Year'], debt_clean['Other Loans']/1000000)

plt.legend(['Real Estate', 'Other Loans', 'Credit Cards'],
           fancybox=True, shadow=True )           
#plt.bar(debt_clean['Year'],debt_clean['Real Estate'], bottom = debt_bar) , bottom = debt_clean['Real Estate']
plt.ticklabel_format(style = "plain", useLocale =True)
plt.title('Debt Types 1987 to 2011')
plt.xlabel('Year')
plt.ylabel('Debt in Hundred Millions (USD)')
plt.savefig('../clean_graphs/stacked_debt_bar.png')

# %%
gdp_data = "../raw-data/gdp_data.csv"
gdp = pd.read_csv(gdp_data)
gdp = gdp[:86]

# %%
gdp = gdp.groupby('Quarter').sum().reset_index()

# %%
plt.grid(which='major', axis='y')
plt.bar(gdp['Quarter'], gdp['GDP'])


plt.xticks(gdp['Quarter'][::4], rotation="vertical")


plt.title('GDP Change 1989 to 2011')
plt.xlabel('Quarter')
plt.ylabel('Percentage Change')
plt.savefig('../clean_graphs/gdp_pct_change.png')

# %%
gdp_data = "../raw-data/gdp_data.csv"
gdp = pd.read_csv(gdp_data)
gdp = gdp[86:113]
gdp = gdp.groupby('Quarter').sum().reset_index()
plt.bar(gdp['Quarter'], gdp['GDP'])
plt.xticks(gdp['Quarter'][::4], rotation="vertical")
plt.title('GDP Change 2011 to 2018')
plt.xlabel('Quarter')
plt.ylabel('Percentage Change')
plt.savefig('../clean_graphs/gdp_pct_change_recent.png')

# %%
# Creates dataframes based around each recession period
first_rec = debt_clean[(debt_clean['Year'] == 1987) | (debt_clean['Year'] == 1988) | (debt_clean['Year'] == 1989) | (debt_clean['Year'] == 1990) | 
          (debt_clean['Year'] == 1991) | (debt_clean['Year'] == 1992) | (debt_clean['Year'] == 1993)]
second_rec = debt_clean[(debt_clean['Year'] == 1998) | (debt_clean['Year'] == 1999) | (debt_clean['Year'] == 2000) | (debt_clean['Year'] == 2001) | 
          (debt_clean['Year'] == 2002) | (debt_clean['Year'] == 2003) | (debt_clean['Year'] == 2004)]
third_rec = debt_clean[(debt_clean['Year'] == 2005) | (debt_clean['Year'] == 2006) | (debt_clean['Year'] == 2007) | (debt_clean['Year'] == 2008) | 
          (debt_clean['Year'] == 2009) | (debt_clean['Year'] == 2010) | (debt_clean['Year'] == 2011)]

# Sums the data for each recession dataframe 
first_rec = first_rec.groupby('Year').sum().reset_index()
second_rec = second_rec.groupby('Year').sum().reset_index()
third_rec = third_rec.groupby('Year').sum().reset_index()

first_rec_one = first_rec[first_rec['Year'] < 1990]
first_rec_peak = first_rec[first_rec['Year'] == 1990]
first_rec_two = first_rec[first_rec['Year'] > 1990]

# %%
plt.bar(first_rec['Year'],first_rec['Real Estate']/1000000)
plt.bar(first_rec['Year'],first_rec['Other Loans']/1000000, bottom = first_rec['Credit Cards']/1000000)
plt.bar(first_rec['Year'],first_rec['Credit Cards']/1000000)

#plt.bar(debt_clean_all_years['Year'],debt_clean_all_years['Other Loans'])
plt.legend(['Real Estate', 'Other Loans', 'Credit Cards'], loc='best', 
           columnspacing=1.0, labelspacing=0.0,
           handletextpad=0.0, handlelength=1.5,
           fancybox=True, shadow=True)
plt.ticklabel_format(style = "plain", useLocale =True)

plt.title('1990 Recession')
plt.xlabel('Year')
plt.ylabel('Debt in Hundreds of Millions (USD)')
#plt.savefig('../clean_graphs/stacked_debt_bar_1990.png')
plt.show()

# %%
plt.bar(second_rec['Year'],second_rec['Real Estate']/1000000)
plt.bar(second_rec['Year'],second_rec['Other Loans']/1000000, bottom = second_rec['Credit Cards']/1000000)
plt.bar(second_rec['Year'],second_rec['Credit Cards']/1000000)
#plt.bar(debt_clean_all_years['Year'],debt_clean_all_years['Other Loans'])
plt.legend(['Real Estate', 'Other Loans', 'Credit Cards'], loc='best', 
           columnspacing=1.0, labelspacing=0.0,
           handletextpad=0.0, handlelength=1.5,
           fancybox=True, shadow=True)
plt.title('2001 Recession')
plt.xlabel('Year')
plt.ylabel('Debt in Hundreds of Millions (USD)')
#plt.savefig('../clean_graphs/stacked_debt_bar_2001.png')
plt.show()

# %%
plt.bar(third_rec['Year'],third_rec['Real Estate']/1000000)
plt.bar(third_rec['Year'],third_rec['Other Loans']/1000000, bottom = third_rec['Credit Cards']/1000000 )
plt.bar(third_rec['Year'],third_rec['Credit Cards']/1000000)
#plt.bar(debt_clean_all_years['Year'],debt_clean_all_years['Other Loans'])
plt.legend(['Real Estate', 'Other Loans', 'Credit Cards'], loc='best', 
           columnspacing=1.0, labelspacing=0.0,
           handletextpad=0.0, handlelength=1.5,
           fancybox=True, shadow=True)
plt.title('2009 Recession')
plt.ylim(0, 4500)

plt.xlabel('Year')
plt.ylabel('Debt in Hundreds of Millions (USD)')
#plt.savefig('../clean_graphs/stacked_debt_bar_2011.png')
plt.show()

# %%
store_col = list(debt_clean.keys())
store_col.pop(-1)
debt_clean['Year']

a_df = pd.DataFrame()
year_order = []
for head in store_col:
    if head == 'Year':
        a_df[head] = debt_clean[head]
    else:
        percentage = debt_clean[head]
        percs = []
        for i in range(1,len(percentage)):
            delta = 0
            delta = ((percentage[i] - percentage[i-1])/percentage[i]) * 100
            percs.append(delta)
        a_df[head] = percs
        a_df['Year'] = debt_clean['Year'] + 1
a_df

def percentage_delta(header):
    empty_df = pd.DataFrame()
    percen = []
    for head in store_col:
        percentages = debt_clean[head]
        percen = []
        for i in range(1,len(percentages)):
            delta = 0
            delta = ((percentages[i] - percentages[i-1])/percentages[i]) * 100
            percen.append(delta)
        empty_df[head] = percen
    empty_df['Year'] = debt_clean['Year'] + 1
    
    return empty_df

# %%
percentage_delta_df = percentage_delta(store_col)
percentage_delta_df.to_csv('../raw-data/debt_percenta_delta.csv')
percentage_delta_df.sort_values('Year')
per_yrs = percentage_delta_df['Year']

# %%
#percentage_delta_df['Other Loans']
#percentage_delta_df
# Out:
#     Total Loans  Other Loans  Credit Cards  Real Estate  Total Past Due  Year
# 0     946685626  245471027.0     102514993    598699606        40563426  1987
# 1    1047845658  257762209.0     116786672    673296777        41180485  1988
# 2    1157141813  266883392.0     130974399    759284022        48058033  1989
# 3    1225215990  266413460.0     132911283    825891247        58032820  1990
# 4    1236973486  250462590.0     138534024    847976872        52539038  1991
# 5    1247429502  247248620.0     135834552    864346330        43288016  1992
# 6    1334881893  263489524.0     153800967    917591402        35896675  1993
# 7    1474612285  296457862.0     187704654    990449769        34451707  1994
# 8    1605144678  314878416.0     217761817   1072504445        41434525  1995
# 9    1690880054  325319914.0     234598883   1130961257        47557076  1996
# 10   1795183871  324818725.0     233832040   1236533106        48603940  1997
# 11   1900306996  336906090.0     227938907   1335461999        50651159  1998
# 12   2050908807  341480122.0     210887298   1498541387        48568598  1999
# 13   2259867396  352174242.0     248052161   1659640993        58015216  2000
# 14   2406884842  357954399.0     265228007   1783702436        65464713  2001
# 15   2746641149  384948237.0     312577515   2049115397        62070487  2002
# 16   3012997432  411909417.0     352091709   2248996306        60210170  2003
# 17   3430774344  423645837.0     409519282   2597609225        56343275  2004
# 18   3787238205  436032918.0     394655962   2956549325        63321345  2005
# 19   4248314500  463509287.0     386946868   3397858345        77396242  2006
# 20   4588235413  514724399.0     436808501   3636702513       112628427  2007
# 21   4791663667  527310794.0     464770322   3799582551       199005998  2008
# 22   4751869743  527520436.0     443100601   3781248706       248397175  2009
# 23   4834797236  511660000.0     708858981   3614278255       225155737  2010
# 24   4718556347  518791166.0     687774531   3511990650       214063792  2011

# %%
plt.bar(percentage_delta_df['Year'],percentage_delta_df['Credit Cards'], bottom = percentage_delta_df['Other Loans'] )




plt.legend(['Other Loans', 'Credit Cards'], loc='upper left',
          fancybox=True, shadow=True)
#plt.xticks(ticks = per_yrs, rotation='vertical')
plt.title('Percent Change of Unsecured Debt From 1987 to 2011')
plt.ylim(-10, 45)

plt.xlabel('Year')
plt.ylabel('Percent Change (%)')
plt.axhline(0, color='black')
#plt.savefig('../clean_graphs/changer_debt_bar.png')
plt.show()

# %%
plt.bar(percentage_delta_df['Year'],percentage_delta_df['Real Estate'])
plt.title('Percent Change of Mortgage Debt From 1987 to 2011')
#plt.ylim(-10, 45)

plt.xlabel('Year')
plt.ylabel('Percent Change (%)')
plt.axhline(0, color='black')
#plt.savefig('../clean_graphs/Real_Eastate_stacked_per_debt_bar.png')
plt.show()

# %%
plt.bar(percentage_delta_df['Year'],percentage_delta_df['Credit Cards'])
plt.title('Percent Change of Credit Card Debt From 1987 to 2011')
#plt.ylim(-10, 45)

plt.xlabel('Year')
plt.ylabel('Percent Change (%)')
plt.axhline(0, color='black')
plt.savefig('../clean_graphs/Credit_Card_per_debt_bar.png')
plt.show()

# %%
plt.bar(percentage_delta_df['Year'],percentage_delta_df['Other Loans'])
plt.title('Percent Change of Other Loans From 1987 to 2011')
#plt.ylim(-10, 45)

plt.xlabel('Year')
plt.ylabel('Percent Change (%)')
plt.axhline(0, color='black')
plt.savefig('../clean_graphs/Other_Loans_per_debt_bar.png')
plt.show()

# %%
first_rec['Ratio Past Due to Total Loans'] = first_rec['Total Past Due'] / first_rec['Total Loans'] 
second_rec['Ratio Past Due to Total Loans'] = second_rec['Total Past Due'] / second_rec['Total Loans'] 
third_rec['Ratio Past Due to Total Loans'] = third_rec['Total Past Due'] / third_rec['Total Loans']

# %%
def per_of_tot(input_df):
    plt.plot(input_df['Year'], input_df['Ratio Past Due to Total Loans'], 
             color='green', marker='o', linestyle='solid')
    plt.plot(input_df['Year'][3], input_df['Ratio Past Due to Total Loans'][3], 
             color='blue', marker='o', linestyle='solid')
    plt.grid()
    plt.title(f"Past Due Debt Percentage of Total Debt")
    plt.xlabel('Year')
    plt.ylabel('Percent of Total Debt')
    plt.figtext(0.5, -0.03,  wrap=True, horizontalalignment='center', fontsize=10)
    plt.savefig(f'../graphs/per_delta_bar_{column_name}.png')
    plt.show()

# %%
def per_of_tot_bar(input_df):
    plt.bar(input_df['Year'], input_df['Ratio Past Due to Total Loans'], 
             color='green')
    plt.grid()
    plt.title(f"Past Due Debt Percentage of Total Debt")
    plt.xlabel('Year')
    plt.ylabel('Percent of Total Debt')
    plt.figtext(0.5, -0.03, wrap=True, horizontalalignment='center', fontsize=10)
    plt.savefig(f'../graphs/per_delta_bar_{column_name}.png')
    plt.show()

# %%
list_of_df = [first_rec, second_rec, third_rec]
for dataframe in list_of_df:
    per_of_tot(dataframe)
    per_of_tot_bar(dataframe)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-c98bafac6d6d> in <module>()
#       1 list_of_df = [first_rec, second_rec, third_rec]
#       2 for dataframe in list_of_df:
# ----> 3     per_of_tot(dataframe)
#       4     per_of_tot_bar(dataframe)
#
# <ipython-input-49-a782f36a907b> in per_of_tot(input_df)
#       8     plt.xlabel('Year')
#       9     plt.ylabel('Percent of Total Debt')
# ---> 10     plt.figtext(0.5, -0.03,  wrap=True, horizontalalignment='center', fontsize=10)
#      11     plt.savefig(f'../graphs/per_delta_bar_{column_name}.png')
#      12     plt.show()
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\pyplot.py in figtext(*args, **kwargs)
#     744 @docstring.copy_dedent(Figure.text)
#     745 def figtext(*args, **kwargs):
# --> 746     return gcf().text(*args, **kwargs)
#     747
#     748
#
# TypeError: text() missing 1 required positional argument: 's'

# %%
gdp_data = "../raw-data/annual_gdp_data.csv"
clean_data = "../raw-data/debt_clean.csv"
gdp = pd.read_csv(gdp_data)
debt = pd.read_csv(clean_data)

# %%
new_df = debt.merge(gdp, on = "Year")
new_df
# Out:
#     Unnamed: 0_x  Total Loans  Other Loans  Credit Cards  Real Estate  \
# 0              0    946685626  245471027.0     102514993    598699606
# 1              2   1157141813  266883392.0     130974399    759284022
# 2              3   1225215990  266413460.0     132911283    825891247
# 3              4   1236973486  250462590.0     138534024    847976872
# 4              5   1247429502  247248620.0     135834552    864346330
# 5              6   1334881893  263489524.0     153800967    917591402
# 6              7   1474612285  296457862.0     187704654    990449769
# 7              8   1605144678  314878416.0     217761817   1072504445
# 8              9   1690880054  325319914.0     234598883   1130961257
# 9             10   1795183871  324818725.0     233832040   1236533106
# 10            11   1900306996  336906090.0     227938907   1335461999
# 11            12   2050908807  341480122.0     210887298   1498541387
# 12            13   2259867396  352174242.0     248052161   1659640993
# 13            14   2406884842  357954399.0     265228007   1783702436
# 14            15   2746641149  384948237.0     312577515   2049115397
# 15            16   3012997432  411909417.0     352091709   2248996306
# 16            18   3787238205  436032918.0     394655962   2956549325
# 17            19   4248314500  463509287.0     386946868   3397858345
# 18            20   4588235413  514724399.0     436808501   3636702513
# 19            21   4791663667  527310794.0     464770322   3799582551
# 20            22   4751869743  527520436.0     443100601   3781248706
# 21            23   4834797236  511660000.0     708858981   3614278255
# 22            24   4718556347  518791166.0     687774531   3511990650
#
#     Total Past Due  Year  Unnamed: 0_y  GDP
# 0         40563426  1987             0  3.5
# 1         48058033  1989             1  3.7
# 2         58032820  1990             2  1.9
# 3         52539038  1991             3 -0.1
# 4         43288016  1992             4  3.5
# 5         35896675  1993             5  2.8
# 6         34451707  1994             6  4.0
# 7         41434525  1995             7  2.7
# 8         47557076  1996             8  3.8
# 9         48603940  1997             9  4.4
# 10        50651159  1998            10  4.5
# 11        48568598  1999            11  4.8
# 12        58015216  2000            12  4.1
# 13        65464713  2001            13  1.0
# 14        62070487  2002            14  1.7
# 15        60210170  2003            15  2.9
# 16        63321345  2005            16  3.5
# 17        77396242  2006            17  2.9
# 18       112628427  2007            18  1.9
# 19       199005998  2008            19 -0.1
# 20       248397175  2009            20 -2.5
# 21       225155737  2010            21  2.6
# 22       214063792  2011            22  1.6

# %%
from scipy import stats
credit_card = new_df["Credit Cards"]
ttl_loan = new_df["Total Loans"]
ttl_past  = new_df["Total Past Due"]
gdp = new_df["GDP"]
plt.subplot(2, 1, 1)
plt.scatter(range(len(credit_card)), credit_card, label="credit_card")
plt.scatter(range(len(ttl_loan)), ttl_loan, label="ttl_loan")
plt.scatter(range(len(ttl_past)), ttl_past, label="ttl_past")
plt.legend()
plt.subplot(2, 1, 2)
plt.hist(credit_card, 25, density=True, alpha=0.3, label="credit_card")
plt.hist(ttl_loan, 25, density=True, alpha=0.3, label="ttl_loan")
plt.hist(ttl_past, 25, density=True, alpha=0.3, label="ttl_past")
plt.axvline(credit_card.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(ttl_loan.mean(), color='k', linestyle='dashed', linewidth=1)
plt.axvline(ttl_past.mean(), color='k', linestyle='dashed', linewidth=1)
plt.legend()

# %%
stats.ttest_ind(ttl_past, gdp, equal_var=False)
# Out:
# Ttest_indResult(statistic=6.031691081884235, pvalue=4.526441776962849e-06)

# %%
stats.f_oneway(gdp, ttl_loan, ttl_past)
# Out:
# F_onewayResult(statistic=75.41560450198821, pvalue=8.972857246567078e-18)

# %%
from sklearn import linear_model
# Initialize model
regression_model = linear_model.LinearRegression()

# Train the model using the mtcars data
regression_model.fit(X = pd.DataFrame(gdp), 
                     y = pd.DataFrame(ttl_past))

# Check trained model y-intercept
print(regression_model.intercept_)

# Check trained model coefficients
print(regression_model.coef_)
# Out:
# [1.4770402e+08]
# [[-24734655.58395295]]

# %%
regression_model.score(X = pd.DataFrame(gdp), 
                       y = pd.DataFrame(ttl_past))
# Out:
# 0.4170358214450272

# %%
lm2.score(X, y)
# Out:
# 0.5599808385640319

# %%
1.4770402e+08 + -24734655.58395295
lm1 = smf.ols(formula='Sales ~ TV + Radio + Newspaper', data=data).fit()
# Out:
# 122969364.41604705

# %%
import seaborn as sns
new_df.shape
new_df
# Out:
#     Unnamed: 0_x  Total Loans  Other Loans  Credit Cards  Real Estate  \
# 0              0    946685626  245471027.0     102514993    598699606
# 1              2   1157141813  266883392.0     130974399    759284022
# 2              3   1225215990  266413460.0     132911283    825891247
# 3              4   1236973486  250462590.0     138534024    847976872
# 4              5   1247429502  247248620.0     135834552    864346330
# 5              6   1334881893  263489524.0     153800967    917591402
# 6              7   1474612285  296457862.0     187704654    990449769
# 7              8   1605144678  314878416.0     217761817   1072504445
# 8              9   1690880054  325319914.0     234598883   1130961257
# 9             10   1795183871  324818725.0     233832040   1236533106
# 10            11   1900306996  336906090.0     227938907   1335461999
# 11            12   2050908807  341480122.0     210887298   1498541387
# 12            13   2259867396  352174242.0     248052161   1659640993
# 13            14   2406884842  357954399.0     265228007   1783702436
# 14            15   2746641149  384948237.0     312577515   2049115397
# 15            16   3012997432  411909417.0     352091709   2248996306
# 16            18   3787238205  436032918.0     394655962   2956549325
# 17            19   4248314500  463509287.0     386946868   3397858345
# 18            20   4588235413  514724399.0     436808501   3636702513
# 19            21   4791663667  527310794.0     464770322   3799582551
# 20            22   4751869743  527520436.0     443100601   3781248706
# 21            23   4834797236  511660000.0     708858981   3614278255
# 22            24   4718556347  518791166.0     687774531   3511990650
#
#     Total Past Due  Year  Unnamed: 0_y  GDP
# 0         40563426  1987             0  3.5
# 1         48058033  1989             1  3.7
# 2         58032820  1990             2  1.9
# 3         52539038  1991             3 -0.1
# 4         43288016  1992             4  3.5
# 5         35896675  1993             5  2.8
# 6         34451707  1994             6  4.0
# 7         41434525  1995             7  2.7
# 8         47557076  1996             8  3.8
# 9         48603940  1997             9  4.4
# 10        50651159  1998            10  4.5
# 11        48568598  1999            11  4.8
# 12        58015216  2000            12  4.1
# 13        65464713  2001            13  1.0
# 14        62070487  2002            14  1.7
# 15        60210170  2003            15  2.9
# 16        63321345  2005            16  3.5
# 17        77396242  2006            17  2.9
# 18       112628427  2007            18  1.9
# 19       199005998  2008            19 -0.1
# 20       248397175  2009            20 -2.5
# 21       225155737  2010            21  2.6
# 22       214063792  2011            22  1.6

# %%
sns.pairplot(new_df, x_vars=['Total Loans','Total Past Due'], y_vars='GDP', size=7, aspect=0.7)

# %%
from sklearn.linear_model import LinearRegression
feature_cols = ['Total Past Due', 'Credit Cards']
X = new_df[feature_cols]
y = new_df.GDP

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# 3.1142652249941007
# [-3.27797389e-08  7.47822791e-09]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
lm1 = smf.ols(formula='GDP ~ Total Loans + Total Past Due + Credit Cards + Other Loans' , data=new_df).fit()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-144-2b3818551500>", line 3, in <module>
#     lm1 = smf.ols(formula='GDP ~ Total Loans + Total Past Due + Credit Cards + Other Loans' , data=new_df).fit()
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\statsmodels\base\model.py", line 155, in from_formula
#     missing=missing)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\statsmodels\formula\formulatools.py", line 65, in handle_formula_data
#     NA_action=na_action)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\highlevel.py", line 310, in dmatrices
#     NA_action, return_type)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\highlevel.py", line 165, in _do_highlevel_design
#     NA_action)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\highlevel.py", line 70, in _try_incr_builders
#     NA_action)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\build.py", line 689, in design_matrix_builders
#     factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\build.py", line 354, in _factors_memorize
#     which_pass = factor.memorize_passes_needed(state, eval_env)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\eval.py", line 474, in memorize_passes_needed
#     subset_names = [name for name in ast_names(self.code)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\eval.py", line 474, in <listcomp>
#     subset_names = [name for name in ast_names(self.code)
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\patsy\eval.py", line 105, in ast_names
#     for node in ast.walk(ast.parse(code)):
#
#   File "C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     Total Past Due
#              ^
# SyntaxError: invalid syntax
